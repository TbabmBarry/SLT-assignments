# %%
import random
import numpy as np
from statistics import mean
from random import randrange
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import time
import sys
from scipy.spatial import distance
# %matplotlib inline

# %% [markdown]
# ## Load Data

# %% [markdown]
# load both train and test data

# %%
train_small = np.genfromtxt(
        'datasets/MNIST_train_small.csv', delimiter=',')
test_small = np.genfromtxt('datasets/MNIST_test_small.csv', delimiter=',')

# %%
X_train_small, y_train_small, X_test_small, y_test_small = train_small[:,1:], train_small[:,0], test_small[:,1:], test_small[:,0]

# %% [markdown]
# ## K-Nearest Neighbor

# %%
class KNearestNeighbors():
    """ K-nearest neighbour aka KNN classifier
    
    Parameters
    -------------
    k : int classes
    p : int parameter p in Minkowski Distance calculation
    
    Attributes
    -------------
    
    """
    
    # initialize parameters in KNN model
    def __init__(self, k, p=2):
        self.k = k
        self.p = p    
    
    def compute_distance(self, X_test):
        distances=distance.cdist(X_test,self.X_train,'minkowski', p = self.p)
        return distances
    
    def fit(self, X, y):
        self.X_train = X
        self.y_train = y
    
    def predict(self, X_test):
        
        #compute distances between 
        distances = self.compute_distance(X_test)
        
        #generate predictions
#         for i in range(n_test):
#             y_index = np.argsort(distances[i, :])
#             k_closests = self.y_train[y_index[:self.k]].astype(int)
#             y_pred[i] = np.argmax(np.bincount(k_closests))
            
        y_indices = np.argsort(distances)
        k_closests = self.y_train[y_indices[:,:self.k]].astype(int)
        bincount = np.array([np.count_nonzero(k_closests == j, axis = 1) for j in range(10)]).transpose()
        
        #random selection
        max_bin_values = np.amax(bincount,axis=1)
        a = np.array([bincount[j] == max_bin_values[j] for j in range(max_bin_values.shape[0])])
        y_pred = np.array([])
        for row in a:
            tmp = np.asarray(np.nonzero(row)).reshape(-1)
            y_pred = np.append(y_pred,np.random.choice(tmp,1,replace=False))      
#         y_pred = np.argmax(bincount,axis = 1)            
        
        return y_pred

# %% [markdown]
# ## Sanity Check

# %%
knn = KNearestNeighbors(3,2)

# %% [markdown]
# ## a. Using Euclidean distance to plot empirical training and test loss as a function of k

# %%
k_neighbors = np.linspace(1, 20, 20, dtype='int')

# %%
plt.figure(figsize=(15,4))
plt.title("Training/Test Accuracy")
plt.xticks(k_neighbors)
plt.xlabel("Number of neighbors")
plt.ylabel("Average Accuracy")
train_acc_results = []
test_acc_results = []
train_loss_results = []
test_loss_results = []
for k in k_neighbors:
    KNN = KNearestNeighbors(k,2)
    KNN.fit(X_train_small,y_train_small)
    y_train_pred = KNN.predict(X_train_small)
    y_test_pred = KNN.predict(X_test_small)
    train_acc = np.sum(y_train_pred == y_train_small)/y_train_small.shape[0]
    test_acc = np.sum(y_test_pred == y_test_small)/y_test_small.shape[0]
    train_loss = np.sum(y_train_pred!=y_train_small)
    test_loss = np.sum(y_test_pred!=y_test_small)
    train_loss_results.append(train_loss)
    test_loss_results.append(test_loss)
    train_acc_results.append(train_acc)
    test_acc_results.append(test_acc)
    
plt.plot(k_neighbors,train_acc_results,label='train')
plt.plot(k_neighbors,test_acc_results,label='test')
plt.legend()
plt.show()

plt.figure(figsize=(15,4))
plt.title("Training/Test loss")
plt.ylabel("Loss")
plt.xlabel("Number of Neighbors")
plt.xticks(k_neighbors)
plt.plot(k_neighbors,train_loss_results,label='train')
plt.plot(k_neighbors,test_loss_results,label='test')
plt.legend()
plt.show()

# %% [markdown]
# ## Cross Validation with KNN

# %% [markdown]
# ### b&c Implement LOOCV to estimate the rick of the k-NN rule for k and p $\in\{1,...,20\}$

# %%
def new_new_cross_val_score(X, y, distances, cv=5, k=5, p=2):
    fold_size = int(y.shape[0]/cv)
    indices = np.arange(y.shape[0])
    np.random.RandomState(123).shuffle(indices)
    result = np.array([])
    for i in range(cv):
        validation_idx = indices[i*fold_size:(i+1)*fold_size]
        train_idx = np.concatenate((indices[:i*fold_size], indices[(i+1)*fold_size:]))
        
        y_indices = np.argsort(distances[validation_idx][:,train_idx])
        k_closests = y[train_idx][y_indices[:,:k]].astype(int)
        bincount = np.array([np.count_nonzero(k_closests == j, axis = 1) for j in range(10)]).transpose()
        
        #random selection
        max_bin_values = np.amax(bincount,axis=1)
        a = np.array([bincount[j] == max_bin_values[j] for j in range(max_bin_values.shape[0])])
        y_pred = np.array([])
        for row in a:
            tmp = np.asarray(np.nonzero(row)).reshape(-1)
            y_pred = np.append(y_pred,np.random.choice(tmp,1,replace=False))      
#         y_pred = np.argmax(bincount,axis = 1)
        
        valid_acc = np.sum(y_pred == y[validation_idx])
        result = np.append(result,valid_acc/validation_idx.shape[0])
    
    return result

# %%
k_neighbors = np.linspace(1, 20, 20, dtype='int')

# %%
distances = distance.pdist(X_train_small, 'minkowski', 2)
distances = distance.squareform(distances)

# %%
# plot the change in the average accuracy according to k
plt.figure(figsize = (15, 4))
plt.title("k-NN")
plt.xticks(k_neighbors)
plt.xlabel("Number of neighbors")
plt.ylabel("Average Accuracy")
results = []
bn, bs = 0, 0
for k in k_neighbors:
    # k-fold cv from scratch for k-NN
    print("start validate", k," neighbors")
    acc = mean(new_new_cross_val_score(X_train_small, y_train_small, distances, cv=y_train_small.shape[0], k=k, p=2))
    results.append(acc)
    print("\nfinished, mean accuracy:",acc)
    if (bs < acc): 
        bn, bs = k, acc
plt.text(bn, bs, f'Neighbor:{bn}, Score:{bs}')
plt.plot(k_neighbors, results)
plt.show()
# Out:
# start validate 1  neighbors
#
# finished, mean accuracy: 0.9193333333333333
# start validate 2  neighbors
#
# finished, mean accuracy: 0.912
# start validate 3  neighbors
#
# finished, mean accuracy: 0.922
# start validate 4  neighbors
#
# finished, mean accuracy: 0.9193333333333333
# start validate 5  neighbors
#
# finished, mean accuracy: 0.9206666666666666
# start validate 6  neighbors
#
# finished, mean accuracy: 0.919
# start validate 7  neighbors
#
# finished, mean accuracy: 0.9163333333333333
# start validate 8  neighbors
#
# finished, mean accuracy: 0.9126666666666666
# start validate 9  neighbors
#
# finished, mean accuracy: 0.9113333333333333
# start validate 10  neighbors
#
# finished, mean accuracy: 0.9086666666666666
# start validate 11  neighbors
#
# finished, mean accuracy: 0.907
# start validate 12  neighbors
#
# finished, mean accuracy: 0.9046666666666666
# start validate 13  neighbors
#
# finished, mean accuracy: 0.9046666666666666
# start validate 14  neighbors
#
# finished, mean accuracy: 0.9043333333333333
# start validate 15  neighbors
#
# finished, mean accuracy: 0.9053333333333333
# start validate 16  neighbors
#
# finished, mean accuracy: 0.8996666666666666
# start validate 17  neighbors
#
# finished, mean accuracy: 0.9006666666666666
# start validate 18  neighbors
#
# finished, mean accuracy: 0.8986666666666666
# start validate 19  neighbors
#
# finished, mean accuracy: 0.8986666666666666
# start validate 20  neighbors
#
# finished, mean accuracy: 0.8983333333333333

# %%
k_neighbors = np.linspace(1, 20, 20, dtype='int')
n_powers = np.linspace(1,15,15,dtype = 'int')

# %%
# plot the change in the average accuracy according to k
plt.figure(figsize = (15, 4))
plt.title("k-NN")
plt.xticks(k_neighbors)
plt.xlabel("Number of neighbors")
plt.ylabel("Average Accuracy")
bp, bn, bs = 0, 0, 0
for p in n_powers:
    results = []
    distances = distance.pdist(X_train_small, 'minkowski', p)
    distances = distance.squareform(distances)
    for k in k_neighbors:
        print(f'Start validation: P:{p}, K:{k}')
        acc = mean(new_new_cross_val_score(X_train_small, y_train_small, distances, cv=y_train_small.shape[0], k=k, p=2))
        if bs < acc: bp, bn, bs = p, k, acc
        results.append(acc)
        print(f"Finished, mean accuracy: {acc:.3%}")
    plt.plot(k_neighbors, results, label=f'P: {p}')
        
plt.text(bn, bs, f'Power:{bp}, Neighbor:{bn}, Score:{bs}')
plt.legend()
plt.show()
# Out:
# Start validation: P:1, K:1
# Finished, mean accuracy: 91.033%
# Start validation: P:1, K:2
# Finished, mean accuracy: 89.533%
# Start validation: P:1, K:3
# Finished, mean accuracy: 90.767%
# Start validation: P:1, K:4
# Finished, mean accuracy: 90.900%
# Start validation: P:1, K:5
# Finished, mean accuracy: 90.467%
# Start validation: P:1, K:6
# Finished, mean accuracy: 90.233%
# Start validation: P:1, K:7
# Finished, mean accuracy: 90.267%
# Start validation: P:1, K:8
# Finished, mean accuracy: 90.300%
# Start validation: P:1, K:9
# Finished, mean accuracy: 90.100%
# Start validation: P:1, K:10
# Finished, mean accuracy: 89.800%
# Start validation: P:1, K:11
# Finished, mean accuracy: 89.733%
# Start validation: P:1, K:12
# Finished, mean accuracy: 89.467%
# Start validation: P:1, K:13
# Finished, mean accuracy: 89.367%
# Start validation: P:1, K:14
# Finished, mean accuracy: 89.400%
# Start validation: P:1, K:15
# Finished, mean accuracy: 89.000%
# Start validation: P:1, K:16
# Finished, mean accuracy: 89.100%
# Start validation: P:1, K:17
# Finished, mean accuracy: 88.733%
# Start validation: P:1, K:18
# Finished, mean accuracy: 88.367%
# Start validation: P:1, K:19
# Finished, mean accuracy: 88.567%
# Start validation: P:1, K:20
# Finished, mean accuracy: 88.433%
# Start validation: P:2, K:1
# Finished, mean accuracy: 91.933%
# Start validation: P:2, K:2
# Finished, mean accuracy: 91.300%
# Start validation: P:2, K:3
# Finished, mean accuracy: 92.167%
# Start validation: P:2, K:4
# Finished, mean accuracy: 91.933%
# Start validation: P:2, K:5
# Finished, mean accuracy: 91.700%
# Start validation: P:2, K:6
# Finished, mean accuracy: 91.667%
# Start validation: P:2, K:7
# Finished, mean accuracy: 91.433%
# Start validation: P:2, K:8
# Finished, mean accuracy: 90.867%
# Start validation: P:2, K:9
# Finished, mean accuracy: 91.300%
# Start validation: P:2, K:10
# Finished, mean accuracy: 91.033%
# Start validation: P:2, K:11
# Finished, mean accuracy: 90.833%
# Start validation: P:2, K:12
# Finished, mean accuracy: 90.767%
# Start validation: P:2, K:13
# Finished, mean accuracy: 90.533%
# Start validation: P:2, K:14
# Finished, mean accuracy: 90.200%
# Start validation: P:2, K:15
# Finished, mean accuracy: 90.433%
# Start validation: P:2, K:16
# Finished, mean accuracy: 90.033%
# Start validation: P:2, K:17
# Finished, mean accuracy: 89.967%
# Start validation: P:2, K:18
# Finished, mean accuracy: 90.033%
# Start validation: P:2, K:19
# Finished, mean accuracy: 90.000%
# Start validation: P:2, K:20
# Finished, mean accuracy: 89.933%
# Start validation: P:3, K:1
# Finished, mean accuracy: 92.467%
# Start validation: P:3, K:2
# Finished, mean accuracy: 91.700%
# Start validation: P:3, K:3
# Finished, mean accuracy: 92.967%
# Start validation: P:3, K:4
# Finished, mean accuracy: 92.533%
# Start validation: P:3, K:5
# Finished, mean accuracy: 92.633%
# Start validation: P:3, K:6
# Finished, mean accuracy: 92.233%
# Start validation: P:3, K:7
# Finished, mean accuracy: 91.767%
# Start validation: P:3, K:8
# Finished, mean accuracy: 91.833%
# Start validation: P:3, K:9
# Finished, mean accuracy: 91.533%
# Start validation: P:3, K:10
# Finished, mean accuracy: 91.600%
# Start validation: P:3, K:11
# Finished, mean accuracy: 91.100%
# Start validation: P:3, K:12
# Finished, mean accuracy: 91.267%
# Start validation: P:3, K:13
# Finished, mean accuracy: 91.200%
# Start validation: P:3, K:14
# Finished, mean accuracy: 91.433%
# Start validation: P:3, K:15
# Finished, mean accuracy: 90.800%
# Start validation: P:3, K:16
# Finished, mean accuracy: 90.467%
# Start validation: P:3, K:17
# Finished, mean accuracy: 90.467%
# Start validation: P:3, K:18
# Finished, mean accuracy: 90.633%
# Start validation: P:3, K:19
# Finished, mean accuracy: 90.133%
# Start validation: P:3, K:20
# Finished, mean accuracy: 90.300%
# Start validation: P:4, K:1
# Finished, mean accuracy: 92.667%
# Start validation: P:4, K:2
# Finished, mean accuracy: 92.000%
# Start validation: P:4, K:3
# Finished, mean accuracy: 93.167%
# Start validation: P:4, K:4
# Finished, mean accuracy: 92.533%
# Start validation: P:4, K:5
# Finished, mean accuracy: 92.700%
# Start validation: P:4, K:6
# Finished, mean accuracy: 92.067%
# Start validation: P:4, K:7
# Finished, mean accuracy: 92.067%
# Start validation: P:4, K:8
# Finished, mean accuracy: 91.900%
# Start validation: P:4, K:9
# Finished, mean accuracy: 92.067%
# Start validation: P:4, K:10
# Finished, mean accuracy: 91.600%
# Start validation: P:4, K:11
# Finished, mean accuracy: 91.933%
# Start validation: P:4, K:12
# Finished, mean accuracy: 91.600%
# Start validation: P:4, K:13
# Finished, mean accuracy: 91.733%
# Start validation: P:4, K:14
# Finished, mean accuracy: 91.467%
# Start validation: P:4, K:15
# Finished, mean accuracy: 91.033%
# Start validation: P:4, K:16
# Finished, mean accuracy: 91.000%
# Start validation: P:4, K:17
# Finished, mean accuracy: 90.933%
# Start validation: P:4, K:18
# Finished, mean accuracy: 90.900%
# Start validation: P:4, K:19
# Finished, mean accuracy: 90.600%
# Start validation: P:4, K:20
# Finished, mean accuracy: 90.533%
# Start validation: P:5, K:1
# Finished, mean accuracy: 92.700%
# Start validation: P:5, K:2
# Finished, mean accuracy: 92.000%
# Start validation: P:5, K:3
# Finished, mean accuracy: 93.400%
# Start validation: P:5, K:4
# Finished, mean accuracy: 93.000%
# Start validation: P:5, K:5
# Finished, mean accuracy: 92.933%
# Start validation: P:5, K:6
# Finished, mean accuracy: 92.900%
# Start validation: P:5, K:7
# Finished, mean accuracy: 92.433%
# Start validation: P:5, K:8
# Finished, mean accuracy: 92.367%
# Start validation: P:5, K:9
# Finished, mean accuracy: 92.000%
# Start validation: P:5, K:10
# Finished, mean accuracy: 92.233%
# Start validation: P:5, K:11
# Finished, mean accuracy: 92.200%
# Start validation: P:5, K:12
# Finished, mean accuracy: 91.667%
# Start validation: P:5, K:13
# Finished, mean accuracy: 91.800%
# Start validation: P:5, K:14
# Finished, mean accuracy: 91.933%
# Start validation: P:5, K:15
# Finished, mean accuracy: 91.500%
# Start validation: P:5, K:16
# Finished, mean accuracy: 91.233%
# Start validation: P:5, K:17
# Finished, mean accuracy: 91.000%
# Start validation: P:5, K:18
# Finished, mean accuracy: 90.900%
# Start validation: P:5, K:19
# Finished, mean accuracy: 90.967%
# Start validation: P:5, K:20
# Finished, mean accuracy: 90.600%
# Start validation: P:6, K:1
# Finished, mean accuracy: 92.867%
# Start validation: P:6, K:2
# Finished, mean accuracy: 92.133%
# Start validation: P:6, K:3
# Finished, mean accuracy: 93.700%
# Start validation: P:6, K:4
# Finished, mean accuracy: 93.367%
# Start validation: P:6, K:5
# Finished, mean accuracy: 92.967%
# Start validation: P:6, K:6
# Finished, mean accuracy: 92.733%
# Start validation: P:6, K:7
# Finished, mean accuracy: 92.433%
# Start validation: P:6, K:8
# Finished, mean accuracy: 92.333%
# Start validation: P:6, K:9
# Finished, mean accuracy: 92.167%
# Start validation: P:6, K:10
# Finished, mean accuracy: 92.133%
# Start validation: P:6, K:11
# Finished, mean accuracy: 92.433%
# Start validation: P:6, K:12
# Finished, mean accuracy: 92.433%
# Start validation: P:6, K:13
# Finished, mean accuracy: 91.867%
# Start validation: P:6, K:14
# Finished, mean accuracy: 91.767%
# Start validation: P:6, K:15
# Finished, mean accuracy: 91.500%
# Start validation: P:6, K:16
# Finished, mean accuracy: 91.667%
# Start validation: P:6, K:17
# Finished, mean accuracy: 91.533%
# Start validation: P:6, K:18
# Finished, mean accuracy: 91.267%
# Start validation: P:6, K:19
# Finished, mean accuracy: 91.267%
# Start validation: P:6, K:20
# Finished, mean accuracy: 91.067%
# Start validation: P:7, K:1
# Finished, mean accuracy: 92.900%
# Start validation: P:7, K:2
# Finished, mean accuracy: 92.000%
# Start validation: P:7, K:3
# Finished, mean accuracy: 94.167%
# Start validation: P:7, K:4
# Finished, mean accuracy: 93.367%
# Start validation: P:7, K:5
# Finished, mean accuracy: 93.200%
# Start validation: P:7, K:6
# Finished, mean accuracy: 92.733%
# Start validation: P:7, K:7
# Finished, mean accuracy: 92.567%
# Start validation: P:7, K:8
# Finished, mean accuracy: 92.667%
# Start validation: P:7, K:9
# Finished, mean accuracy: 92.400%
# Start validation: P:7, K:10
# Finished, mean accuracy: 92.467%
# Start validation: P:7, K:11
# Finished, mean accuracy: 92.333%
# Start validation: P:7, K:12
# Finished, mean accuracy: 92.200%
# Start validation: P:7, K:13
# Finished, mean accuracy: 92.033%
# Start validation: P:7, K:14
# Finished, mean accuracy: 91.833%
# Start validation: P:7, K:15
# Finished, mean accuracy: 91.633%
# Start validation: P:7, K:16
# Finished, mean accuracy: 91.700%
# Start validation: P:7, K:17
# Finished, mean accuracy: 91.267%
# Start validation: P:7, K:18
# Finished, mean accuracy: 91.433%
# Start validation: P:7, K:19
# Finished, mean accuracy: 91.500%
# Start validation: P:7, K:20
# Finished, mean accuracy: 91.200%
# Start validation: P:8, K:1
# Finished, mean accuracy: 93.067%
# Start validation: P:8, K:2
# Finished, mean accuracy: 92.167%
# Start validation: P:8, K:3
# Finished, mean accuracy: 94.100%
# Start validation: P:8, K:4
# Finished, mean accuracy: 93.167%
# Start validation: P:8, K:5
# Finished, mean accuracy: 93.333%
# Start validation: P:8, K:6
# Finished, mean accuracy: 92.667%
# Start validation: P:8, K:7
# Finished, mean accuracy: 92.800%
# Start validation: P:8, K:8
# Finished, mean accuracy: 92.533%
# Start validation: P:8, K:9
# Finished, mean accuracy: 92.500%
# Start validation: P:8, K:10
# Finished, mean accuracy: 92.733%
# Start validation: P:8, K:11
# Finished, mean accuracy: 92.533%
# Start validation: P:8, K:12
# Finished, mean accuracy: 92.367%
# Start validation: P:8, K:13
# Finished, mean accuracy: 92.000%
# Start validation: P:8, K:14
# Finished, mean accuracy: 91.767%
# Start validation: P:8, K:15
# Finished, mean accuracy: 91.833%
# Start validation: P:8, K:16
# Finished, mean accuracy: 91.767%
# Start validation: P:8, K:17
# Finished, mean accuracy: 91.667%
# Start validation: P:8, K:18
# Finished, mean accuracy: 91.333%
# Start validation: P:8, K:19
# Finished, mean accuracy: 91.167%
# Start validation: P:8, K:20
# Finished, mean accuracy: 91.333%
# Start validation: P:9, K:1
# Finished, mean accuracy: 93.067%
# Start validation: P:9, K:2
# Finished, mean accuracy: 92.700%
# Start validation: P:9, K:3
# Finished, mean accuracy: 94.000%
# Start validation: P:9, K:4
# Finished, mean accuracy: 93.400%
# Start validation: P:9, K:5
# Finished, mean accuracy: 93.433%
# Start validation: P:9, K:6
# Finished, mean accuracy: 92.700%
# Start validation: P:9, K:7
# Finished, mean accuracy: 92.800%
# Start validation: P:9, K:8
# Finished, mean accuracy: 92.467%
# Start validation: P:9, K:9
# Finished, mean accuracy: 92.933%
# Start validation: P:9, K:10
# Finished, mean accuracy: 92.767%
# Start validation: P:9, K:11
# Finished, mean accuracy: 92.267%
# Start validation: P:9, K:12
# Finished, mean accuracy: 92.533%
# Start validation: P:9, K:13
# Finished, mean accuracy: 92.100%
# Start validation: P:9, K:14
# Finished, mean accuracy: 92.000%
# Start validation: P:9, K:15
# Finished, mean accuracy: 92.133%
# Start validation: P:9, K:16
# Finished, mean accuracy: 91.500%
# Start validation: P:9, K:17
# Finished, mean accuracy: 91.500%
# Start validation: P:9, K:18
# Finished, mean accuracy: 91.567%
# Start validation: P:9, K:19
# Finished, mean accuracy: 91.300%
# Start validation: P:9, K:20
# Finished, mean accuracy: 91.300%
# Start validation: P:10, K:1
# Finished, mean accuracy: 92.967%
# Start validation: P:10, K:2
# Finished, mean accuracy: 91.933%
# Start validation: P:10, K:3
# Finished, mean accuracy: 93.700%
# Start validation: P:10, K:4
# Finished, mean accuracy: 93.300%
# Start validation: P:10, K:5
# Finished, mean accuracy: 93.400%
# Start validation: P:10, K:6
# Finished, mean accuracy: 93.133%
# Start validation: P:10, K:7
# Finished, mean accuracy: 92.800%
# Start validation: P:10, K:8
# Finished, mean accuracy: 92.633%
# Start validation: P:10, K:9
# Finished, mean accuracy: 92.933%
# Start validation: P:10, K:10
# Finished, mean accuracy: 92.400%
# Start validation: P:10, K:11
# Finished, mean accuracy: 92.367%
# Start validation: P:10, K:12
# Finished, mean accuracy: 92.367%
# Start validation: P:10, K:13
# Finished, mean accuracy: 92.100%
# Start validation: P:10, K:14
# Finished, mean accuracy: 91.867%
# Start validation: P:10, K:15
# Finished, mean accuracy: 91.900%
# Start validation: P:10, K:16
# Finished, mean accuracy: 91.667%
# Start validation: P:10, K:17
# Finished, mean accuracy: 91.833%
# Start validation: P:10, K:18
# Finished, mean accuracy: 91.367%
# Start validation: P:10, K:19
# Finished, mean accuracy: 91.233%
# Start validation: P:10, K:20
# Finished, mean accuracy: 91.167%
# Start validation: P:11, K:1
# Finished, mean accuracy: 92.833%
# Start validation: P:11, K:2
# Finished, mean accuracy: 92.167%
# Start validation: P:11, K:3
# Finished, mean accuracy: 93.767%
# Start validation: P:11, K:4
# Finished, mean accuracy: 93.567%
# Start validation: P:11, K:5
# Finished, mean accuracy: 93.133%
# Start validation: P:11, K:6
# Finished, mean accuracy: 93.200%
# Start validation: P:11, K:7
# Finished, mean accuracy: 93.067%
# Start validation: P:11, K:8
# Finished, mean accuracy: 92.600%
# Start validation: P:11, K:9
# Finished, mean accuracy: 92.633%
# Start validation: P:11, K:10
# Finished, mean accuracy: 92.733%
# Start validation: P:11, K:11
# Finished, mean accuracy: 92.633%
# Start validation: P:11, K:12
# Finished, mean accuracy: 92.167%
# Start validation: P:11, K:13
# Finished, mean accuracy: 92.067%
# Start validation: P:11, K:14
# Finished, mean accuracy: 92.100%
# Start validation: P:11, K:15
# Finished, mean accuracy: 91.767%
# Start validation: P:11, K:16
# Finished, mean accuracy: 91.633%
# Start validation: P:11, K:17
# Finished, mean accuracy: 91.700%
# Start validation: P:11, K:18
# Finished, mean accuracy: 91.500%
# Start validation: P:11, K:19
# Finished, mean accuracy: 91.567%
# Start validation: P:11, K:20
# Finished, mean accuracy: 91.067%
# Start validation: P:12, K:1
# Finished, mean accuracy: 92.933%
# Start validation: P:12, K:2
# Finished, mean accuracy: 91.767%
# Start validation: P:12, K:3
# Finished, mean accuracy: 93.533%
# Start validation: P:12, K:4
# Finished, mean accuracy: 93.267%
# Start validation: P:12, K:5
# Finished, mean accuracy: 93.333%
# Start validation: P:12, K:6
# Finished, mean accuracy: 93.000%
# Start validation: P:12, K:7
# Finished, mean accuracy: 92.933%
# Start validation: P:12, K:8
# Finished, mean accuracy: 92.467%
# Start validation: P:12, K:9
# Finished, mean accuracy: 92.733%
# Start validation: P:12, K:10
# Finished, mean accuracy: 92.833%
# Start validation: P:12, K:11
# Finished, mean accuracy: 92.467%
# Start validation: P:12, K:12
# Finished, mean accuracy: 92.300%
# Start validation: P:12, K:13
# Finished, mean accuracy: 92.400%
# Start validation: P:12, K:14
# Finished, mean accuracy: 92.167%
# Start validation: P:12, K:15
# Finished, mean accuracy: 91.867%
# Start validation: P:12, K:16
# Finished, mean accuracy: 91.667%
# Start validation: P:12, K:17
# Finished, mean accuracy: 91.667%
# Start validation: P:12, K:18
# Finished, mean accuracy: 91.433%
# Start validation: P:12, K:19
# Finished, mean accuracy: 91.500%
# Start validation: P:12, K:20
# Finished, mean accuracy: 91.133%
# Start validation: P:13, K:1
# Finished, mean accuracy: 92.967%
# Start validation: P:13, K:2
# Finished, mean accuracy: 92.433%
# Start validation: P:13, K:3
# Finished, mean accuracy: 93.567%
# Start validation: P:13, K:4
# Finished, mean accuracy: 93.433%
# Start validation: P:13, K:5
# Finished, mean accuracy: 93.300%
# Start validation: P:13, K:6
# Finished, mean accuracy: 92.633%
# Start validation: P:13, K:7
# Finished, mean accuracy: 92.733%
# Start validation: P:13, K:8
# Finished, mean accuracy: 92.267%
# Start validation: P:13, K:9
# Finished, mean accuracy: 92.667%
# Start validation: P:13, K:10
# Finished, mean accuracy: 92.667%
# Start validation: P:13, K:11
# Finished, mean accuracy: 92.433%
# Start validation: P:13, K:12
# Finished, mean accuracy: 92.433%
# Start validation: P:13, K:13
# Finished, mean accuracy: 92.267%
# Start validation: P:13, K:14
# Finished, mean accuracy: 92.233%
# Start validation: P:13, K:15
# Finished, mean accuracy: 91.967%
# Start validation: P:13, K:16
# Finished, mean accuracy: 91.967%
# Start validation: P:13, K:17
# Finished, mean accuracy: 91.833%
# Start validation: P:13, K:18
# Finished, mean accuracy: 91.567%
# Start validation: P:13, K:19
# Finished, mean accuracy: 91.533%
# Start validation: P:13, K:20
# Finished, mean accuracy: 91.167%
# Start validation: P:14, K:1
# Finished, mean accuracy: 92.933%
# Start validation: P:14, K:2
# Finished, mean accuracy: 91.600%
# Start validation: P:14, K:3
# Finished, mean accuracy: 93.500%
# Start validation: P:14, K:4
# Finished, mean accuracy: 93.367%
# Start validation: P:14, K:5
# Finished, mean accuracy: 93.433%
# Start validation: P:14, K:6
# Finished, mean accuracy: 93.033%
# Start validation: P:14, K:7
# Finished, mean accuracy: 92.867%
# Start validation: P:14, K:8
# Finished, mean accuracy: 92.367%
# Start validation: P:14, K:9
# Finished, mean accuracy: 92.867%
# Start validation: P:14, K:10
# Finished, mean accuracy: 92.600%
# Start validation: P:14, K:11
# Finished, mean accuracy: 92.533%
# Start validation: P:14, K:12
# Finished, mean accuracy: 92.700%
# Start validation: P:14, K:13
# Finished, mean accuracy: 92.467%
# Start validation: P:14, K:14
# Finished, mean accuracy: 92.000%
# Start validation: P:14, K:15
# Finished, mean accuracy: 91.967%
# Start validation: P:14, K:16
# Finished, mean accuracy: 91.867%
# Start validation: P:14, K:17
# Finished, mean accuracy: 91.867%
# Start validation: P:14, K:18
# Finished, mean accuracy: 91.433%
# Start validation: P:14, K:19
# Finished, mean accuracy: 91.367%
# Start validation: P:14, K:20
# Finished, mean accuracy: 91.367%
# Start validation: P:15, K:1
# Finished, mean accuracy: 92.967%
# Start validation: P:15, K:2
# Finished, mean accuracy: 91.733%
# Start validation: P:15, K:3
# Finished, mean accuracy: 93.200%
# Start validation: P:15, K:4
# Finished, mean accuracy: 93.433%
# Start validation: P:15, K:5
# Finished, mean accuracy: 93.200%
# Start validation: P:15, K:6
# Finished, mean accuracy: 93.067%
# Start validation: P:15, K:7
# Finished, mean accuracy: 92.833%
# Start validation: P:15, K:8
# Finished, mean accuracy: 92.833%
# Start validation: P:15, K:9
# Finished, mean accuracy: 92.800%
# Start validation: P:15, K:10
# Finished, mean accuracy: 92.400%
# Start validation: P:15, K:11
# Finished, mean accuracy: 92.433%
# Start validation: P:15, K:12
# Finished, mean accuracy: 92.467%
# Start validation: P:15, K:13
# Finished, mean accuracy: 92.533%
# Start validation: P:15, K:14
# Finished, mean accuracy: 92.200%
# Start validation: P:15, K:15
# Finished, mean accuracy: 92.067%
# Start validation: P:15, K:16
# Finished, mean accuracy: 91.733%
# Start validation: P:15, K:17
# Finished, mean accuracy: 91.733%
# Start validation: P:15, K:18
# Finished, mean accuracy: 91.500%
# Start validation: P:15, K:19
# Finished, mean accuracy: 91.433%
# Start validation: P:15, K:20
# Finished, mean accuracy: 91.400%

# %% [markdown]
# ## d.Improve performance of k-NN by data preprocessing

# %%
from scipy.stats import norm
import math
from sklearn import preprocessing
def get_nth_quartile(data, n):  
    if n < 1 or n > 3:
        return false
    data.sort()
    position = 1 + (len(data)-1)*n/4
    pos_integer = int(math.modf(position)[1])
    pos_decimal = position - pos_integer
    quartile = data[pos_integer - 1] + (data[pos_integer] - data[pos_integer - 1])*pos_decimal
    return quartile

def min_max_scaling(data):
    return np.where(data.ptp(0) == 0, data, (data - data.min(0)) / data.ptp(0))

def standard_scaling(data):
    return preprocessing.normalize(data)

def max_abs_scaling(data):
    return np.where(abs(data.max(0)) == 0, data, data / abs(data.max(0)))

def robust_scaling(data):
#     return RobustScaler().fit(data).transform(data)
    temp=data.copy()
    tmp = data.copy()
    for i in range(len(tmp)):
        quartile=get_nth_quartile(tmp[i],1)
        quartiletre=get_nth_quartile(tmp[i],3)
        median=get_nth_quartile(tmp[i],2)
        if quartiletre-quartile != 0:
            temp[i]=[((temp[i][j] - median) / (quartiletre-quartile)) for j in range(len(temp[i]))]
    return temp

def unit_scaling(data):
    temp=np.ndarray(data.shape)
    for i in range(len(data)):
        for j in range(len(data[i])):
            if data[i][j] != 0:
                temp[i][j]=1
    return temp

# %%
X_train_mm = min_max_scaling(X_train_small)
X_test_mm = min_max_scaling(X_test_small)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in true_divide
#   from ipykernel import kernelapp as app

# %%
X_train_ma = max_abs_scaling(X_train_small)
X_test_ma = max_abs_scaling(X_test_small)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: RuntimeWarning: invalid value encountered in true_divide

# %%
X_train_nr = standard_scaling(X_train_small)
X_test_nr = standard_scaling(X_test_small)

# %%
X_train_rs = robust_scaling(X_train_small)
X_test_rs = robust_scaling(X_test_small)

# %%
X_train_unit = unit_scaling(X_train_small)
X_test_unit = unit_scaling(X_test_small)

# %%
k_neighbors = np.linspace(1, 5, 5, dtype='int')
distances_mm = distance.pdist(X_train_mm, 'minkowski', 2)
distances_mm = distance.squareform(distances_mm)

distances_ma = distance.pdist(X_train_ma, 'minkowski', 2)
distances_ma = distance.squareform(distances_ma)

distances_nr = distance.pdist(X_train_nr, 'minkowski', 2)
distances_nr = distance.squareform(distances_nr)

# %%
distances_rs = distance.pdist(X_train_rs, 'minkowski', 2)
distances_rs = distance.squareform(distances_rs)

# %%
distances_unit = distance.pdist(X_train_unit, 'minkowski', 2)
distances_unit = distance.squareform(distances_unit)

# %%
k_neighbors = np.linspace(1, 20, 20, dtype='int')

# %%
# plot the change in the average accuracy according to k
plt.figure(figsize = (15, 4))
plt.title("k-NN")
plt.xticks(k_neighbors)
plt.xlabel("Number of neighbors")
plt.ylabel("Average Accuracy")
knn0 = []
knn1 = []
knn2 = []
knn3 = []
knn4 = []
knn5 = []


for k in k_neighbors:
    print("start validate", k," neighbors")
    # k-fold cv from scratch for k-NN
    acc0 = mean(new_new_cross_val_score(X_train_small,y_train_small,distances, cv=y_train_small.shape[0], k=k, p=2))
    acc1 = mean(new_new_cross_val_score(X_train_mm,y_train_small,distances_mm, cv=y_train_small.shape[0], k=k, p=2))
    print("mm finished")
    acc2 = mean(new_new_cross_val_score(X_train_ma,y_train_small,distances_ma, cv=y_train_small.shape[0], k=k, p=2))
    acc3 = mean(new_new_cross_val_score(X_train_nr,y_train_small,distances_nr, cv=y_train_small.shape[0], k=k, p=2))
    acc4 = mean(new_new_cross_val_score(X_train_rs,y_train_small,distances_rs, cv=y_train_small.shape[0], k=k, p=2))
    acc5 = mean(new_new_cross_val_score(X_train_unit,y_train_small,distances_unit, cv=y_train_small.shape[0], k=k, p=2))
    knn0.append(acc0)
    knn1.append(acc1)
    knn2.append(acc2)
    knn3.append(acc3)
    knn4.append(acc4)
    knn5.append(acc5)

plt.plot(k_neighbors, knn0, label="control group",marker='.')
plt.plot(k_neighbors, knn1, label="max_min",marker='.')
plt.plot(k_neighbors, knn2, label="max_abs",marker='.')
plt.plot(k_neighbors, knn3, label="normalize",marker='.')
plt.plot(k_neighbors, knn4, label="robust",marker='.')
plt.plot(k_neighbors, knn5, label="unit",marker='.')
plt.legend()
plt.show()
# Out:
# start validate 1  neighbors
# mm finished
# start validate 2  neighbors
# mm finished
# start validate 3  neighbors
# mm finished
# start validate 4  neighbors
# mm finished
# start validate 5  neighbors
# mm finished
# start validate 6  neighbors
# mm finished
# start validate 7  neighbors
# mm finished
# start validate 8  neighbors
# mm finished
# start validate 9  neighbors
# mm finished
# start validate 10  neighbors
# mm finished
# start validate 11  neighbors
# mm finished
# start validate 12  neighbors
# mm finished
# start validate 13  neighbors
# mm finished
# start validate 14  neighbors
# mm finished
# start validate 15  neighbors
# mm finished
# start validate 16  neighbors
# mm finished
# start validate 17  neighbors
# mm finished
# start validate 18  neighbors
# mm finished
# start validate 19  neighbors
# mm finished
# start validate 20  neighbors
# mm finished

# %% [markdown]
# ## PCA: Dimensionality Reduction

# %%
pca = PCA(n_components=50)
X_train_pca = pca.fit_transform(X_train_small)
X_test_pca = pca.transform(X_test_small)
# X_train_pca = pca.fit_transform(train_small[:,1:])
# X_test_pca = pca.transform(test_small[:,1:])

# %%
n_components = np.linspace(5,50,10, dtype='int')
k_neighbors = np.linspace(1,7,7, dtype='int')

# %%
# plot the change in the average accuracy according to k
plt.figure(figsize = (15, 4))
plt.title("k-NN")
plt.xlabel("Number of components")
plt.ylabel("Average Accuracy")
bc, bn, bs = 0, 0, 0
for k in k_neighbors:
    knn = []
    for n_component in n_components:
        KNN = KNearestNeighbors(k, 2)
        KNN.fit(X_train_pca[:,:n_component], train_small[:,0])
        y_pred = KNN.predict(X_test_pca[:,:n_component])
        score = sum(y_pred==test_small[:,0])/test_small[:,0].shape[0]
        if score > bs:
            bc, bn, bs = n_component, k, score
        knn.append(score)
    plt.plot(n_components, knn, label=f'Neighbor: {k}')
plt.text(bc, bs,f"  Component:{bc}, Neighbor:{bn}, ACC:{bs}")
plt.legend()
plt.show()

# %%
random.seed(1)
# plot the change in the average accuracy according to k
plt.figure(figsize = (15, 4))
plt.title("k-NN")
plt.xlabel("Number of neighbors")
plt.ylabel("Average Accuracy")
for p in range(1, 7):
    knn = []
    for k in range(2, 13):
        # k-fold cv from scratch for k-NN
        acc = mean(cross_val_score(train_small, cv=12, k=k, p=p))
        knn.append(acc)
    plt.plot(range(2, 13), knn, label=f'P: {p}')
plt.legend()
plt.show()
#         print(f'Accuracy: {acc:.3f}, K: {k}, P: {p}')
# plt.figure(figsize = (15, 4))
# plt.title("k-NN")
# plt.xlabel("Number of neighbors")
# plt.ylabel("Average Accuracy")
# plt.plot(range(2, 13), knn);
